# %%
using Pkg
Pkg.add("Luxor")
Pkg.add("Colors")
Pkg.add("Images")
Pkg.add("ImageMagick")
# Out:
#     Updating registry at `C:\Users\jakev\.julia\registries\General`
#     Updating git-repo `https://github.com/JuliaRegistries/General.git`
#     Updating registry at `C:\Users\jakev\.julia\registries\JuliaSimRegistry.toml`
#    Resolving package versions...
#     Updating `C:\Users\jakev\source\repos\SciMLBook\Project.toml`
#   [ae8d54c2] + Luxor v3.5.0
#     Updating `C:\Users\jakev\source\repos\SciMLBook\Manifest.toml`
#   [159f3aea] + Cairo v1.0.5
#   [5789e2e9] + FileIO v1.16.0
#   [a2bd30eb] + Graphics v1.1.2
#   [e5e0dc1b] + Juno v0.8.4
#   [ae8d54c2] + Luxor v3.5.0
#   [e89f7d12] + Media v0.5.0
#   [c4c386cf] + Rsvg v1.0.0
#   [925c91fb] + Librsvg_jll v2.52.4+0
#   [36c8627f] + Pango_jll v1.50.9+0
#   [da03df04] + gdk_pixbuf_jll v2.42.8+0
#    Resolving package versions...
#     Updating `C:\Users\jakev\source\repos\SciMLBook\Project.toml`
#   [5ae59095] + Colors v0.12.8
#   No Changes to `C:\Users\jakev\source\repos\SciMLBook\Manifest.toml`
# ...

# %%
using Luxor
using Colors
using Images
using ImageMagick

# %%
sciml_logo_url = "https://raw.githubusercontent.com/SciML/SciMLAssets/main/logo/musm_fixes_final/JuliaDiffEq_icon.svg"
# Out:
# "https://raw.githubusercontent.com/SciML/SciMLAssets/main/logo/musm_fixes_final/JuliaDiffEq_icon.svg"

# %%
sciml_logo = download(sciml_logo_url)
# Out:
# "C:\\Users\\jakev\\AppData\\Local\\Temp\\jl_VyJ4xwN4lk"

# %%
using Luxor, Colors
@draw begin
    # draw book
    Drawing(4_400, 4_400, "sciml-book-logo.svg")
    origin()
    background("transparent")
    const sciml_blue = "#213055"
    🐢 = Turtle()
    Pencolor(🐢, sciml_blue)
    Penwidth(🐢, 52)
    squircle(Point(0,0), 1_600, 2_000; action = :fill, rt = 0.1)
    squircle(Point(120, 180), 1_600, 2_000; action = :stroke, rt = 0.1)
    # layer logo
    sciml = readsvg(sciml_logo)
    transform([6.4 0 0 6.4 0 0])
    placeimage(sciml, Point(-120, -120))
    Pencolor(🐢, "#f6f5fa")
    fontsize(42)
    fontface("JuliaMono")
    text("The SciML Book", Point(0, -160), halign=:center, valign=:center)
    finish()
    preview()
end
